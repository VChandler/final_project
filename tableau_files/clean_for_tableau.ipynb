# %%
import pandas as pd

# %%
df = pd.read_csv('SpotifyFeatures.csv')
df.head()
# Out:
#     genre        artist_name                          track_name  \
# 0   Anime  Capcom Sound Team                     Zangief's Theme
# 1   Movie     Henri Salvador  Coeur Brisé à Prendre - Remastered
# 2  Reggae          Mike Love                          Earthlings
# 3    Jazz       Don Philippe                           Fewerdolr
# 4   Dance               ZAYN                      Still Got Time
#
#                  track_id  popularity  acousticness  danceability  \
# 0  00021Wy6AyMbLP2tqij86e          13         0.234         0.617
# 1  000CzNKC8PEt1yC3L8dqwV           5         0.249         0.518
# 2  000DfZJww8KiixTKuk9usJ          30         0.366         0.631
# 3  000EWWBkYaREzsBplYjUag          39         0.815         0.768
# 4  000xQL6tZNLJzIrtIgxqSl          70         0.131         0.748
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0       169173   0.862          0.976000   G    0.1410   -12.855  Major
# 1       130653   0.805          0.000000   F    0.3330    -6.248  Major
# 2       357573   0.513          0.000004   D    0.1090    -6.376  Major
# 3       104924   0.137          0.922000  C#    0.1130   -13.284  Minor
# 4       188491   0.627          0.000000   G    0.0852    -6.029  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0514  129.578          4-Apr    0.886
# 1       0.0407   79.124          4-Apr    0.841
# 2       0.0293  120.365          4-Apr    0.307
# 3       0.0747   76.430          4-Apr    0.560
# 4       0.0644  120.963          4-Apr    0.524

# %%
# If popularity is 50 or more, hit column = 1; else 0
df.loc[df['popularity'] >= 50, 'hit'] = 1
df.loc[df['popularity'] < 50, 'hit'] = 0
df.head()
# Out:
#     genre        artist_name                          track_name  \
# 0   Anime  Capcom Sound Team                     Zangief's Theme
# 1   Movie     Henri Salvador  Coeur Brisé à Prendre - Remastered
# 2  Reggae          Mike Love                          Earthlings
# 3    Jazz       Don Philippe                           Fewerdolr
# 4   Dance               ZAYN                      Still Got Time
#
#                  track_id  popularity  acousticness  danceability  \
# 0  00021Wy6AyMbLP2tqij86e          13         0.234         0.617
# 1  000CzNKC8PEt1yC3L8dqwV           5         0.249         0.518
# 2  000DfZJww8KiixTKuk9usJ          30         0.366         0.631
# 3  000EWWBkYaREzsBplYjUag          39         0.815         0.768
# 4  000xQL6tZNLJzIrtIgxqSl          70         0.131         0.748
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0       169173   0.862          0.976000   G    0.1410   -12.855  Major
# 1       130653   0.805          0.000000   F    0.3330    -6.248  Major
# 2       357573   0.513          0.000004   D    0.1090    -6.376  Major
# 3       104924   0.137          0.922000  C#    0.1130   -13.284  Minor
# 4       188491   0.627          0.000000   G    0.0852    -6.029  Major
#
#    speechiness    tempo time_signature  valence  hit
# 0       0.0514  129.578          4-Apr    0.886  0.0
# 1       0.0407   79.124          4-Apr    0.841  0.0
# 2       0.0293  120.365          4-Apr    0.307  0.0
# 3       0.0747   76.430          4-Apr    0.560  0.0
# 4       0.0644  120.963          4-Apr    0.524  1.0

# %%
# Check number of genres
genre_count = df.genre.value_counts()
genre_count
# Out:
# Comedy              9673
# Electronic          8848
# Folk                8782
# Soundtrack          8770
# Reggae              8712
# Classical           8684
# Anime               8635
# Jazz                8557
# Reggaeton           8551
# Opera               8271
# World               8179
# Hip-Hop             8031
# Ska                 8029
# Movie               7803
# Blues               7307
# Country             7078
# R&B                 6897
# Dance               6775
# Children's Music    5402
# Soul                4898
# Children’s Music    4810
# Indie               3977
# Pop                 3158
# Rock                3073
# Alternative         2072
# Rap                 1683
# A Capella            119
# Name: genre, dtype: int64

# %%
# Drops a capella, comedy, anime and Children’s Music
df2 = df[~(df.genre.isin(['A Capella', 'Comedy', 'Children’s Music', 'Anime']))]

# %%
# Clusters genres
df2.loc[(df['genre'] == 'Hip-Hop') | (df['genre'] == 'R&B') | (df['genre'] == 'Rap') | (df['genre'] == 'Soul'), 'genre2'] = 'Hip_Hop_R&B'
df2.loc[(df['genre'] == 'Movie') | (df['genre'] == 'Soundtrack'), 'genre2'] = 'Cinema'
df2.loc[(df['genre'] == 'Jazz') | (df['genre'] == 'Blues'), 'genre2'] = 'Jazz_Blues'
df2.loc[(df['genre'] == 'Folk') | (df['genre'] == 'Country'), 'genre2'] = 'Folk_Country'
df2.loc[(df['genre'] == 'Electronic') | (df['genre'] == 'Dance'), 'genre2'] = 'Danceclub'
df2.loc[(df['genre'] == 'World') | (df['genre'] == 'Reggaeton'), 'genre2'] = 'World'
df2.loc[(df['genre'] == 'Rock') | (df['genre'] == 'Alternative'), 'genre2'] = 'Rock'
df2.loc[(df['genre'] == 'Classical') | (df['genre'] == 'Opera'), 'genre2'] = 'Classical'
df2.loc[(df['genre'] == 'Ska') | (df['genre'] == 'Reggae'), 'genre2'] = 'Ska_Reggae'
df2.loc[(df["genre"] == "Children's Music"), "genre2"] = "Childrens"
df2.loc[(df['genre'] == 'Pop'), 'genre2'] = 'Pop'
df2.loc[(df['genre'] == 'Indie'), 'genre2'] = 'Indie'

# Check number of genres
new_genre_count = df2.genre2.value_counts()
new_genre_count
# Out:
# /Users/ellejacobs/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/ellejacobs/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Hip_Hop_R&B     21509
# Classical       16955
# Ska_Reggae      16741
# World           16730
# Cinema          16573
# Jazz_Blues      15864
# Folk_Country    15860
# Danceclub       15623
# Childrens        5402
# Rock             5145
# Indie            3977
# Pop              3158
# Name: genre2, dtype: int64

# %%
df2.head()
# Out:
#        genre     artist_name                          track_name  \
# 1      Movie  Henri Salvador  Coeur Brisé à Prendre - Remastered
# 2     Reggae       Mike Love                          Earthlings
# 3       Jazz    Don Philippe                           Fewerdolr
# 4      Dance            ZAYN                      Still Got Time
# 6  Reggaeton   Justin Quiles                 No Quieren Que Gane
#
#                  track_id  popularity  acousticness  danceability  \
# 1  000CzNKC8PEt1yC3L8dqwV           5         0.249         0.518
# 2  000DfZJww8KiixTKuk9usJ          30         0.366         0.631
# 3  000EWWBkYaREzsBplYjUag          39         0.815         0.768
# 4  000xQL6tZNLJzIrtIgxqSl          70         0.131         0.748
# 6  001bQcMKt86oNbnWne4EAB          41         0.231         0.747
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 1       130653   0.805          0.000000   F    0.3330    -6.248  Major
# 2       357573   0.513          0.000004   D    0.1090    -6.376  Major
# 3       104924   0.137          0.922000  C#    0.1130   -13.284  Minor
# 4       188491   0.627          0.000000   G    0.0852    -6.029  Major
# 6       179466   0.583          0.000000   F    0.0443    -7.072  Major
#
#    speechiness    tempo time_signature  valence  hit      genre2
# 1       0.0407   79.124          4-Apr   0.8410  0.0      Cinema
# 2       0.0293  120.365          4-Apr   0.3070  0.0  Ska_Reggae
# 3       0.0747   76.430          4-Apr   0.5600  0.0  Jazz_Blues
# 4       0.0644  120.963          4-Apr   0.5240  1.0   Danceclub
# 6       0.0575  114.071          4-Apr   0.0381  0.0       World

# %%
# dropping genre for first pass of data
df2.drop(['genre'], axis = 1, inplace=True)
df2.head()
# Out:
# /Users/ellejacobs/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       artist_name                          track_name                track_id  \
# 1  Henri Salvador  Coeur Brisé à Prendre - Remastered  000CzNKC8PEt1yC3L8dqwV
# 2       Mike Love                          Earthlings  000DfZJww8KiixTKuk9usJ
# 3    Don Philippe                           Fewerdolr  000EWWBkYaREzsBplYjUag
# 4            ZAYN                      Still Got Time  000xQL6tZNLJzIrtIgxqSl
# 6   Justin Quiles                 No Quieren Que Gane  001bQcMKt86oNbnWne4EAB
#
#    popularity  acousticness  danceability  duration_ms  energy  \
# 1           5         0.249         0.518       130653   0.805
# 2          30         0.366         0.631       357573   0.513
# 3          39         0.815         0.768       104924   0.137
# 4          70         0.131         0.748       188491   0.627
# 6          41         0.231         0.747       179466   0.583
#
#    instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 1          0.000000   F    0.3330    -6.248  Major       0.0407   79.124
# 2          0.000004   D    0.1090    -6.376  Major       0.0293  120.365
# 3          0.922000  C#    0.1130   -13.284  Minor       0.0747   76.430
# 4          0.000000   G    0.0852    -6.029  Major       0.0644  120.963
# 6          0.000000   F    0.0443    -7.072  Major       0.0575  114.071
#
#   time_signature  valence  hit      genre2
# 1          4-Apr   0.8410  0.0      Cinema
# 2          4-Apr   0.3070  0.0  Ska_Reggae
# 3          4-Apr   0.5600  0.0  Jazz_Blues
# 4          4-Apr   0.5240  1.0   Danceclub
# 6          4-Apr   0.0381  0.0       World

# %%
# rename genre2 to genre
df2.rename(columns = {'genre2': 'genre'}, inplace = True)
# Out:
# /Users/ellejacobs/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Creates dataframe with artist, track name and id
tracks_for_tableau = df2[['artist_name', 'track_name', 'track_id']].copy()
tracks_for_tableau.head()
# Out:
#       artist_name                          track_name                track_id
# 1  Henri Salvador  Coeur Brisé à Prendre - Remastered  000CzNKC8PEt1yC3L8dqwV
# 2       Mike Love                          Earthlings  000DfZJww8KiixTKuk9usJ
# 3    Don Philippe                           Fewerdolr  000EWWBkYaREzsBplYjUag
# 4            ZAYN                      Still Got Time  000xQL6tZNLJzIrtIgxqSl
# 6   Justin Quiles                 No Quieren Que Gane  001bQcMKt86oNbnWne4EAB

# %%
# Drops artist name, track name
df2.drop(['artist_name', 'track_name'], axis = 1, inplace=True)
df2.head()
# Out:
# /Users/ellejacobs/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                  track_id  popularity  acousticness  danceability  \
# 1  000CzNKC8PEt1yC3L8dqwV           5         0.249         0.518
# 2  000DfZJww8KiixTKuk9usJ          30         0.366         0.631
# 3  000EWWBkYaREzsBplYjUag          39         0.815         0.768
# 4  000xQL6tZNLJzIrtIgxqSl          70         0.131         0.748
# 6  001bQcMKt86oNbnWne4EAB          41         0.231         0.747
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 1       130653   0.805          0.000000   F    0.3330    -6.248  Major
# 2       357573   0.513          0.000004   D    0.1090    -6.376  Major
# 3       104924   0.137          0.922000  C#    0.1130   -13.284  Minor
# 4       188491   0.627          0.000000   G    0.0852    -6.029  Major
# 6       179466   0.583          0.000000   F    0.0443    -7.072  Major
#
#    speechiness    tempo time_signature  valence  hit       genre
# 1       0.0407   79.124          4-Apr   0.8410  0.0      Cinema
# 2       0.0293  120.365          4-Apr   0.3070  0.0  Ska_Reggae
# 3       0.0747   76.430          4-Apr   0.5600  0.0  Jazz_Blues
# 4       0.0644  120.963          4-Apr   0.5240  1.0   Danceclub
# 6       0.0575  114.071          4-Apr   0.0381  0.0       World

# %%
#express duration in minutes instead of milliseconds
df2['duration_m'] = df2['duration_ms']/60000
df2 = df2.reindex(sorted(df2.columns), axis=1)
df2.head()
# Out:
# /Users/ellejacobs/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    acousticness  danceability  duration_m  duration_ms  energy       genre  \
# 1         0.249         0.518    2.177550       130653   0.805      Cinema
# 2         0.366         0.631    5.959550       357573   0.513  Ska_Reggae
# 3         0.815         0.768    1.748733       104924   0.137  Jazz_Blues
# 4         0.131         0.748    3.141517       188491   0.627   Danceclub
# 6         0.231         0.747    2.991100       179466   0.583       World
#
#    hit  instrumentalness key  liveness  loudness   mode  popularity  \
# 1  0.0          0.000000   F    0.3330    -6.248  Major           5
# 2  0.0          0.000004   D    0.1090    -6.376  Major          30
# 3  0.0          0.922000  C#    0.1130   -13.284  Minor          39
# 4  1.0          0.000000   G    0.0852    -6.029  Major          70
# 6  0.0          0.000000   F    0.0443    -7.072  Major          41
#
#    speechiness    tempo time_signature                track_id  valence
# 1       0.0407   79.124          4-Apr  000CzNKC8PEt1yC3L8dqwV   0.8410
# 2       0.0293  120.365          4-Apr  000DfZJww8KiixTKuk9usJ   0.3070
# 3       0.0747   76.430          4-Apr  000EWWBkYaREzsBplYjUag   0.5600
# 4       0.0644  120.963          4-Apr  000xQL6tZNLJzIrtIgxqSl   0.5240
# 6       0.0575  114.071          4-Apr  001bQcMKt86oNbnWne4EAB   0.0381

# %%
# Drops duration_ms
df2.drop(['duration_ms'], axis = 1, inplace=True)
df2.head()
# Out:
#    acousticness  danceability  duration_m  energy       genre  hit  \
# 1         0.249         0.518    2.177550   0.805      Cinema  0.0
# 2         0.366         0.631    5.959550   0.513  Ska_Reggae  0.0
# 3         0.815         0.768    1.748733   0.137  Jazz_Blues  0.0
# 4         0.131         0.748    3.141517   0.627   Danceclub  1.0
# 6         0.231         0.747    2.991100   0.583       World  0.0
#
#    instrumentalness key  liveness  loudness   mode  popularity  speechiness  \
# 1          0.000000   F    0.3330    -6.248  Major           5       0.0407
# 2          0.000004   D    0.1090    -6.376  Major          30       0.0293
# 3          0.922000  C#    0.1130   -13.284  Minor          39       0.0747
# 4          0.000000   G    0.0852    -6.029  Major          70       0.0644
# 6          0.000000   F    0.0443    -7.072  Major          41       0.0575
#
#      tempo time_signature                track_id  valence
# 1   79.124          4-Apr  000CzNKC8PEt1yC3L8dqwV   0.8410
# 2  120.365          4-Apr  000DfZJww8KiixTKuk9usJ   0.3070
# 3   76.430          4-Apr  000EWWBkYaREzsBplYjUag   0.5600
# 4  120.963          4-Apr  000xQL6tZNLJzIrtIgxqSl   0.5240
# 6  114.071          4-Apr  001bQcMKt86oNbnWne4EAB   0.0381

# %%
df2.to_csv("songs_for_tableau.csv", index = False)

# %%
tracks_for_tableau.to_csv("tracks_for_tableau.csv", index=False)
